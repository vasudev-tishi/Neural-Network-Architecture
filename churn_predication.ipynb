# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv('/content/drive/MyDrive/Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.drop(columns=['RowNumber' , 'CustomerId' , 'Surname'] , inplace=True)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# Age
# 37    478
# 38    477
# 35    474
# 36    456
# 34    447
#      ...
# 84      2
# 82      1
# 88      1
# 85      1
# 83      1
# Name: count, Length: 70, dtype: int64

# %%
df =  pd.get_dummies(df, columns=['Geography','Gender'], drop_first=True,dtype=int)

# %%
df.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0               1        101348.88       1                  0
# 1               1        112542.58       0                  0
# 2               0        113931.57       1                  0
# 3               0         93826.63       0                  0
# 4               1         79084.10       0                  0
#
#    Geography_Spain  Gender_Male
# 0                0            0
# 1                1            0
# 2                0            0
# 3                0            0
# 4                1            0

# %%
X = df.drop(columns=['Exited'])
y = df['Exited'].values

# %%
x_train , x_test , y_train , y_test = train_test_split(X, y , test_size= 0.2 , random_state=32)

# %%
x_train
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 4004          530   41       4       0.00              2          0
# 9121          618   40       0       0.00              1          1
# 1800          713   59       3       0.00              2          1
# 1081          461   35       8       0.00              1          1
# 8230          758   32       4  162657.64              2          1
# ...           ...  ...     ...        ...            ...        ...
# 8444          792   70       3       0.00              2          1
# 7571          718   52       8   79475.30              3          1
# 4030          603   42       6       0.00              1          1
# 9526          642   18       5  111183.53              2          0
# 9771          480   39       5  121626.90              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 4004               1        147606.71                  0                1
# 9121               0        119059.13                  0                0
# 1800               1         62700.08                  0                0
# 1081               0        132295.95                  0                1
# 8230               1        115525.13                  1                0
# ...              ...              ...                ...              ...
# 8444               1        172240.27                  0                0
# 7571               1         32421.32                  0                0
# 4030               1         90437.87                  0                1
# 9526               1         10063.75                  1                0
# 9771               1         82438.13                  0                1
#
#       Gender_Male
# 4004            0
# 9121            0
# 1800            0
# 1081            0
# 8230            1
# ...           ...
# 8444            0
# 7571            1
# 4030            0
# 9526            1
# 9771            1
#
# [8000 rows x 11 columns]

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

# %%
model.add(Dense(11,activation='sigmoid',input_dim=11))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 11)             │           132 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 132 (528.00 B)
#  Trainable params: 132 (528.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.add(Dense(11,activation='sigmoid'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 11)             │           132 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            12 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 276 (1.08 KB)
#  Trainable params: 276 (1.08 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,batch_size=50,epochs=50,verbose=1,validation_split=0.2)
# Out:
# Epoch 1/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2015 - loss: 1.1672 - val_accuracy: 0.2194 - val_loss: 0.7545
# Epoch 2/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4574 - loss: 0.6957 - val_accuracy: 0.7806 - val_loss: 0.5828
# Epoch 3/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7972 - loss: 0.5568 - val_accuracy: 0.7806 - val_loss: 0.5307
# Epoch 4/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8051 - loss: 0.5057 - val_accuracy: 0.7806 - val_loss: 0.5119
# Epoch 5/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8025 - loss: 0.4883 - val_accuracy: 0.7806 - val_loss: 0.5020
# Epoch 6/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8127 - loss: 0.4658 - val_accuracy: 0.7806 - val_loss: 0.4946
# Epoch 7/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8106 - loss: 0.4573 - val_accuracy: 0.7806 - val_loss: 0.4872
# Epoch 8/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7977 - loss: 0.4688 - val_accuracy: 0.7806 - val_loss: 0.4794
# Epoch 9/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7994 - loss: 0.4586 - val_accuracy: 0.7806 - val_loss: 0.4717
# Epoch 10/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7982 - loss: 0.4528 - val_accuracy: 0.7806 - val_loss: 0.4641
# Epoch 11/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7965 - loss: 0.4486 - val_accuracy: 0.7806 - val_loss: 0.4569
# Epoch 12/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7981 - loss: 0.4418 - val_accuracy: 0.7806 - val_loss: 0.4508
# Epoch 13/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8024 - loss: 0.4322 - val_accuracy: 0.7900 - val_loss: 0.4457
# Epoch 14/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8152 - loss: 0.4185 - val_accuracy: 0.8062 - val_loss: 0.4418
# Epoch 15/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8227 - loss: 0.4192 - val_accuracy: 0.8106 - val_loss: 0.4388
# Epoch 16/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8247 - loss: 0.4141 - val_accuracy: 0.8200 - val_loss: 0.4358
# Epoch 17/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8211 - loss: 0.4236 - val_accuracy: 0.8181 - val_loss: 0.4340
# Epoch 18/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8198 - loss: 0.4208 - val_accuracy: 0.8169 - val_loss: 0.4322
# Epoch 19/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8168 - loss: 0.4197 - val_accuracy: 0.8181 - val_loss: 0.4308
# Epoch 20/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8298 - loss: 0.4081 - val_accuracy: 0.8250 - val_loss: 0.4287
# Epoch 21/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8326 - loss: 0.4072 - val_accuracy: 0.8250 - val_loss: 0.4276
# Epoch 22/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8224 - loss: 0.4192 - val_accuracy: 0.8269 - val_loss: 0.4260
# Epoch 23/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8269 - loss: 0.4126 - val_accuracy: 0.8288 - val_loss: 0.4246
# Epoch 24/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8242 - loss: 0.4120 - val_accuracy: 0.8300 - val_loss: 0.4234
# Epoch 25/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8370 - loss: 0.4012 - val_accuracy: 0.8313 - val_loss: 0.4220
# Epoch 26/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8297 - loss: 0.4111 - val_accuracy: 0.8313 - val_loss: 0.4211
# Epoch 27/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8429 - loss: 0.3955 - val_accuracy: 0.8331 - val_loss: 0.4200
# Epoch 28/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8358 - loss: 0.4032 - val_accuracy: 0.8375 - val_loss: 0.4186
# Epoch 29/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8332 - loss: 0.3996 - val_accuracy: 0.8375 - val_loss: 0.4177
# Epoch 30/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8339 - loss: 0.3994 - val_accuracy: 0.8369 - val_loss: 0.4173
# Epoch 31/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8322 - loss: 0.4053 - val_accuracy: 0.8381 - val_loss: 0.4161
# Epoch 32/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8379 - loss: 0.4005 - val_accuracy: 0.8388 - val_loss: 0.4154
# Epoch 33/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8333 - loss: 0.4040 - val_accuracy: 0.8381 - val_loss: 0.4143
# Epoch 34/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8344 - loss: 0.4070 - val_accuracy: 0.8375 - val_loss: 0.4139
# Epoch 35/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8363 - loss: 0.3932 - val_accuracy: 0.8388 - val_loss: 0.4130
# Epoch 36/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8366 - loss: 0.4016 - val_accuracy: 0.8388 - val_loss: 0.4124
# Epoch 37/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8441 - loss: 0.3965 - val_accuracy: 0.8388 - val_loss: 0.4120
# Epoch 38/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8444 - loss: 0.3873 - val_accuracy: 0.8394 - val_loss: 0.4111
# Epoch 39/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8357 - loss: 0.4007 - val_accuracy: 0.8388 - val_loss: 0.4108
# Epoch 40/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.8336 - loss: 0.4005 - val_accuracy: 0.8388 - val_loss: 0.4104
# Epoch 41/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8399 - loss: 0.3946 - val_accuracy: 0.8381 - val_loss: 0.4092
# Epoch 42/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8321 - loss: 0.4025 - val_accuracy: 0.8394 - val_loss: 0.4096
# Epoch 43/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8385 - loss: 0.3960 - val_accuracy: 0.8381 - val_loss: 0.4083
# Epoch 44/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8439 - loss: 0.3833 - val_accuracy: 0.8394 - val_loss: 0.4083
# Epoch 45/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8364 - loss: 0.3991 - val_accuracy: 0.8394 - val_loss: 0.4078
# Epoch 46/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8410 - loss: 0.3889 - val_accuracy: 0.8381 - val_loss: 0.4072
# Epoch 47/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8358 - loss: 0.4002 - val_accuracy: 0.8388 - val_loss: 0.4069
# Epoch 48/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8437 - loss: 0.3802 - val_accuracy: 0.8381 - val_loss: 0.4062
# Epoch 49/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8398 - loss: 0.3916 - val_accuracy: 0.8413 - val_loss: 0.4064
# Epoch 50/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8414 - loss: 0.3854 - val_accuracy: 0.8400 - val_loss: 0.4054

# %%
pre = model.predict(x_test)
pre
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# array([[0.04633256],
#        [0.2449384 ],
#        [0.19966355],
#        ...,
#        [0.2010182 ],
#        [0.5370387 ],
#        [0.06776462]], dtype=float32)

# %%
pre = pre.argmax(axis=-1)
pre
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
accuracy_score(y_test,pre)
# Out:
# 0.7915

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
